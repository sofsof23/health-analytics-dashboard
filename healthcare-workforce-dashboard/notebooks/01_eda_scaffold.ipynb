# %% [markdown]
# # Healthcare Workforce — Exploratory Data Analysis
#
# **Status:** 🚧 Scaffold — to be completed on Day 3 of the build plan.
#
# This notebook holds the exploratory data analysis and methodology writeup for the dashboard. Each section has a TODO marker for what's coming.

# %%
import pandas as pd
import plotly.express as px
from pathlib import Path

DATA = Path('../data/mock_data.csv')
df = pd.read_csv(DATA)
df.head()

# %% [markdown]
# ## 1. Data shape and coverage
#
# _TODO Day 3: missing-data audit, year coverage by country, indicator availability matrix._

# %%
df.info()
df.isna().sum()

# %% [markdown]
# ## 2. Distributions by region
#
# _TODO: histograms and box plots per WHO region for each workforce indicator. Comment on the dispersion within Eastern Mediterranean specifically (GCC vs non-GCC)._

# %%
# TODO Day 3

# %% [markdown]
# ## 3. Workforce vs outcomes correlations
#
# _TODO: correlation matrix and scatter plots between physicians/nurses density and life expectancy / NCD mortality. Note where the relationship breaks down._

# %%
# TODO Day 3

# %% [markdown]
# ## 4. GCC focus
#
# _TODO: deep dive on GCC countries — trajectory over time, peer comparison, position vs global benchmarks._

# %%
GCC = ['SAU', 'ARE', 'QAT', 'KWT', 'BHR', 'OMN']
df[df['iso3'].isin(GCC)].head()

# %% [markdown]
# ## 5. Methodology notes
#
# _TODO: indicator definitions (linked to WHO metadata), cleaning decisions, limitations, sources, how missing data was handled._
